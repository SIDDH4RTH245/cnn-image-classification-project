# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/cnn-image-classification-project/blob/main/notebooks/01_data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1: Load Dataset

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print(X_train.shape)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# (50000, 32, 32, 3)

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
import matplotlib.pyplot as plt

plt.imshow(X_train[0])
plt.title(f"Label: {y_train[0]}")
plt.show()
